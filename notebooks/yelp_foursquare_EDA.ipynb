# %%
import pandas as pd
import requests
import os
import json
from pprint import pprint

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#get data from the FS API
def get_venues_fs(latitude, longitude, radius, api_key, categories):
    """
    Get venues from foursquare with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """
    # create the URL
    url = "https://api.foursquare.com/v3/places/search"
    # create the parameters
    params = {
        "ll" : f"{latitude},{longitude}",
        "radius" : radius,
        "categories" : categories,

    }
    # create the headers
    headers = {
        "accept": "application/json",
        "Authorization": api_key
        }
    # make the request
    resp = requests.get(url=url, params=params, headers=headers)
    # return the response
    return resp

# %%
test=get_venues_fs(43.2557,-79.8711, 1000, 'fsq3TJEGvNWjyX35XQXnbout8f/9UIv1+vRbARZ+E4WYlgU=', None)

# %%
print(test)
# Out:
# <Response [200]>

# %%
test.json()
# Out:
# {'results': [{'fsq_id': '4d93318162ad5481a9ec7b4b',
#    'categories': [{'id': 10027,
#      'name': 'Museum',
#      'short_name': 'Museum',
#      'plural_name': 'Museums',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 172,
#    'geocodes': {'main': {'latitude': 43.254593, 'longitude': -79.87211},
#     'roof': {'latitude': 43.254596, 'longitude': -79.871991}},
#    'link': '/v3/places/4d93318162ad5481a9ec7b4b',
#    'location': {'address': '41 Jackson St W',
#     'country': 'CA',
#     'formatted_address': '41 Jackson St W, Hamilton ON L8P 1L3',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1L3',
#     'region': 'ON'},
#    'name': 'Whitehern Historic House and Garden',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50a19225e4b035e940520491',
#    'categories': [{'id': 13305,
#      'name': 'Burrito Restaurant',
#      'short_name': 'Burritos',
#      'plural_name': 'Burrito Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#       'suffix': '.png'}}],
#    'chains': [{'id': '2d108fae-d80a-482b-a105-57ab79c2581e',
#      'name': 'Burrito Boyz'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 43.255691, 'longitude': -79.867215},
#     'roof': {'latitude': 43.255691, 'longitude': -79.867215}},
#    'link': '/v3/places/50a19225e4b035e940520491',
#    'location': {'address': '66 King St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '66 King St E, Hamilton ON L8N 1A6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1A6',
#     'region': 'ON'},
#    'name': 'Burrito Boyz',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '55de230f498eecf46f6652a2',
#    'categories': [{'id': 13306,
#      'name': 'Taco Restaurant',
#      'short_name': 'Tacos',
#      'plural_name': 'Taco Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 343,
#    'geocodes': {'drop_off': {'latitude': 43.257143, 'longitude': -79.86724},
#     'main': {'latitude': 43.257258, 'longitude': -79.867202},
#     'roof': {'latitude': 43.257258, 'longitude': -79.867202}},
#    'link': '/v3/places/55de230f498eecf46f6652a2',
#    'location': {'address': '41 King William St',
#     'country': 'CA',
#     'cross_street': 'Hughson',
#     'formatted_address': '41 King William St (Hughson), Hamilton ON L8R 1A2',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 1A2',
#     'region': 'ON'},
#    'name': 'The Mule',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b628f4bf964a5205a4b2ae3',
#    'categories': [{'id': 17065,
#      'name': 'Farmers Market',
#      'short_name': 'Farmers Market',
#      'plural_name': 'Farmers Markets',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 395,
#    'geocodes': {'main': {'latitude': 43.259041, 'longitude': -79.870193},
#     'roof': {'latitude': 43.259041, 'longitude': -79.870193}},
#    'link': '/v3/places/4b628f4bf964a5205a4b2ae3',
#    'location': {'address': '55 York Blvd',
#     'country': 'CA',
#     'cross_street': 'at James',
#     'formatted_address': '55 York Blvd (at James), Hamilton ON L8R 3K1',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 3K1',
#     'region': 'ON'},
#    'name': "Hamilton Farmers' Market",
#    'related_places': {'children': [{'fsq_id': '5d7bd06979bb820008173f0e',
#       'categories': [{'id': 13026,
#         'name': 'BBQ Joint',
#         'short_name': 'BBQ',
#         'plural_name': 'BBQ Joints',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#          'suffix': '.png'}}],
#       'name': 'Saltlick Smokehouse'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '511d7162e4b084a5d1f26958',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 357,
#    'geocodes': {'drop_off': {'latitude': 43.25803, 'longitude': -79.873899},
#     'main': {'latitude': 43.2582, 'longitude': -79.873853},
#     'roof': {'latitude': 43.2582, 'longitude': -79.873853}},
#    'link': '/v3/places/511d7162e4b084a5d1f26958',
#    'location': {'address': '152 King St W',
#     'country': 'CA',
#     'cross_street': 'Bay And King',
#     'formatted_address': '152 King St W (Bay And King), Hamilton ON L8P 1A5',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1A5',
#     'region': 'ON'},
#    'name': 'The George Hamilton',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b5e5923f964a520b78a29e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13031,
#      'name': 'Burger Joint',
#      'short_name': 'Burgers',
#      'plural_name': 'Burger Joints',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13338,
#      'name': 'Seafood Restaurant',
#      'short_name': 'Seafood',
#      'plural_name': 'Seafood Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 409,
#    'geocodes': {'drop_off': {'latitude': 43.251943, 'longitude': -79.870017},
#     'main': {'latitude': 43.252066, 'longitude': -79.869987},
#     'roof': {'latitude': 43.252066, 'longitude': -79.869987}},
#    'link': '/v3/places/4b5e5923f964a520b78a29e3',
#    'location': {'address': '23 Augusta St',
#     'country': 'CA',
#     'cross_street': 'Hughson St.',
#     'formatted_address': '23 Augusta St (Hughson St.), Hamilton ON L8N 1P6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P6',
#     'region': 'ON'},
#    'name': 'The Ship',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b01f834f964a520e64622e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 420,
#    'geocodes': {'drop_off': {'latitude': 43.252037, 'longitude': -79.870397},
#     'main': {'latitude': 43.25192, 'longitude': -79.870426},
#     'roof': {'latitude': 43.25192, 'longitude': -79.870426}},
#    'link': '/v3/places/4b01f834f964a520e64622e3',
#    'location': {'address': '20 Augusta St',
#     'country': 'CA',
#     'cross_street': 'James St.',
#     'formatted_address': '20 Augusta St (James St.), Hamilton ON L8N 1P7',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P7',
#     'region': 'ON'},
#    'name': 'The Pheasant Plucker',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b6a4bc5f964a52024d12be3',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13134,
#      'name': 'Comfort Food Restaurant',
#      'short_name': 'Comfort Food',
#      'plural_name': 'Comfort Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 436,
#    'geocodes': {'main': {'latitude': 43.251462, 'longitude': -79.872017},
#     'roof': {'latitude': 43.251462, 'longitude': -79.872017}},
#    'link': '/v3/places/4b6a4bc5f964a52024d12be3',
#    'location': {'address': '1 Duke St',
#     'country': 'CA',
#     'cross_street': 'at James St. South',
#     'formatted_address': '1 Duke St (at James St. South), Hamilton ON L8P 1W9',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1W9',
#     'region': 'ON'},
#    'name': 'One Duke Restaurant & Lounge',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '591534a12aff31013acefff6',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13029,
#      'name': 'Brewery',
#      'short_name': 'Brewery',
#      'plural_name': 'Breweries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.25949, 'longitude': -79.867997},
#     'roof': {'latitude': 43.25949, 'longitude': -79.867997}},
#    'link': '/v3/places/591534a12aff31013acefff6',
#    'location': {'address': '107 James St N',
#     'country': 'CA',
#     'cross_street': 'at York Blvd',
#     'formatted_address': '107 James St N (at York Blvd), Hamilton ON L8R 2K6',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 2K6',
#     'region': 'ON'},
#    'name': 'Merit Brewing',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4cb0ca4baef16dcbc327b454',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'short_name': 'Diner',
#      'plural_name': 'Diners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}},
#     {'id': 13072,
#      'name': 'Asian Restaurant',
#      'short_name': 'Asian',
#      'plural_name': 'Asian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 517,
#    'geocodes': {'main': {'latitude': 43.254244, 'longitude': -79.865672},
#     'roof': {'latitude': 43.254244, 'longitude': -79.865672}},
#    'link': '/v3/places/4cb0ca4baef16dcbc327b454',
#    'location': {'address': '100 Main St E',
#     'address_extended': '# 100',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '100 Main St E, Hamilton ON L8N 3W4',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 3W4',
#     'region': 'ON'},
#    'name': 'Tea Hut',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.2557,
#      'longitude': -79.8711},
#     'radius': 1000}}}}

# %%
import pandas as pd
available_bikes=pd.read_csv('..\\data\\available_bikes.csv')
available_bikes
# Out:
#            Station Name   Latitude  Longitude  Bikes Available
# 0          Hess at king  43.259126 -79.877212                4
# 1         Bayfront Park  43.269288 -79.871327               13
# 2       Bay at Strachan  43.267859 -79.867923                3
# 3       Bay at Mulberry  43.263198 -79.871803                6
# 4             City Hall  43.256132 -79.874499                0
# ..                  ...        ...        ...              ...
# 140     Westdale Aviary  43.264869 -79.907480                3
# 141    Hunter GO Centre  43.253330 -79.869533                5
# 142    Westdale Village  43.262015 -79.905088               25
# 143    Cannon at Ottawa  43.247565 -79.818050                3
# 144  Van Wagner's Beach  43.260008 -79.766388                8
#
# [145 rows x 4 columns]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests

url = "https://api.foursquare.com/v3/places/search?ll=43.2557%2C-79.8711"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3TJEGvNWjyX35XQXnbout8f/9UIv1+vRbARZ+E4WYlgU="
}

response = requests.get(url, headers=headers)

print(response.text)

# Define category IDs for bike-related venues
bike_rental_category_id = '4e4c9077bd41f78e849722f9'  


# Function to query Foursquare API for venues near a given location
def get_nearby_venues(ll, radius, category_id):
    params = {
        # 'client_id': CLIENT_ID,
        # 'client_secret': CLIENT_SECRET,
        # 'v': VERSION,
        'll': ll,
        'radius': radius,
        'categoryId': category_id
    }
    headers = {
    "accept": "application/json",
    "Authorization": "fsq3TJEGvNWjyX35XQXnbout8f/9UIv1+vRbARZ+E4WYlgU="
}
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
       # return response.json()['response']['venues']
        return response.json()
    else:
        print(f'Error: {response.status_code} - {response.text}')
        return None
# Out:
# {"results":[{"fsq_id":"4b5e5923f964a520b78a29e3","categories":[{"id":13018,"name":"Pub","short_name":"Pub","plural_name":"Pubs","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13031,"name":"Burger Joint","short_name":"Burgers","plural_name":"Burger Joints","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/burger_","suffix":".png"}},{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":409,"geocodes":{"drop_off":{"latitude":43.251943,"longitude":-79.870017},"main":{"latitude":43.252066,"longitude":-79.869987},"roof":{"latitude":43.252066,"longitude":-79.869987}},"link":"/v3/places/4b5e5923f964a520b78a29e3","location":{"address":"23 Augusta St","country":"CA","cross_street":"Hughson St.","formatted_address":"23 Augusta St (Hughson St.), Hamilton ON L8N 1P6","locality":"Hamilton","postcode":"L8N 1P6","region":"ON"},"name":"The Ship","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"4b01f834f964a520e64622e3","categories":[{"id":13018,"name":"Pub","short_name":"Pub","plural_name":"Pubs","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13068,"name":"American Restaurant","short_name":"American","plural_name":"American Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13236,"name":"Italian Restaurant","short_name":"Italian","plural_name":"Italian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":420,"geocodes":{"drop_off":{"latitude":43.252037,"longitude":-79.870397},"main":{"latitude":43.25192,"longitude":-79.870426},"roof":{"latitude":43.25192,"longitude":-79.870426}},"link":"/v3/places/4b01f834f964a520e64622e3","location":{"address":"20 Augusta St","country":"CA","cross_street":"James St.","formatted_address":"20 Augusta St (James St.), Hamilton ON L8N 1P7","locality":"Hamilton","postcode":"L8N 1P7","region":"ON"},"name":"The Pheasant Plucker","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"591534a12aff31013acefff6","categories":[{"id":13003,"name":"Bar","short_name":"Bar","plural_name":"Bars","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13029,"name":"Brewery","short_name":"Brewery","plural_name":"Breweries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/brewery_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":491,"geocodes":{"main":{"latitude":43.25949,"longitude":-79.867997},"roof":{"latitude":43.25949,"longitude":-79.867997}},"link":"/v3/places/591534a12aff31013acefff6","location":{"address":"107 James St N","country":"CA","cross_street":"at York Blvd","formatted_address":"107 James St N (at York Blvd), Hamilton ON L8R 2K6","locality":"Hamilton","postcode":"L8R 2K6","region":"ON"},"name":"Merit Brewing","related_places":{},"timezone":"America/Toronto"},{"fsq_id":"5036724be4b001c520354587","categories":[{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"Unsure","distance":922,"geocodes":{"drop_off":{"latitude":43.253761,"longitude":-79.860001},"main":{"latitude":43.253614,"longitude":-79.860049},"roof":{"latitude":43.253614,"longitude":-79.860049}},"link":"/v3/places/503672 ...

# %%
test=get_nearby_venues ((43.2557,-79.8711), 1000, None)
# Out:
# {'results': [{'fsq_id': '4d93318162ad5481a9ec7b4b',
#    'categories': [{'id': 10027,
#      'name': 'Museum',
#      'short_name': 'Museum',
#      'plural_name': 'Museums',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 172,
#    'geocodes': {'main': {'latitude': 43.254593, 'longitude': -79.87211},
#     'roof': {'latitude': 43.254596, 'longitude': -79.871991}},
#    'link': '/v3/places/4d93318162ad5481a9ec7b4b',
#    'location': {'address': '41 Jackson St W',
#     'country': 'CA',
#     'formatted_address': '41 Jackson St W, Hamilton ON L8P 1L3',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1L3',
#     'region': 'ON'},
#    'name': 'Whitehern Historic House and Garden',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '50a19225e4b035e940520491',
#    'categories': [{'id': 13305,
#      'name': 'Burrito Restaurant',
#      'short_name': 'Burritos',
#      'plural_name': 'Burrito Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#       'suffix': '.png'}}],
#    'chains': [{'id': '2d108fae-d80a-482b-a105-57ab79c2581e',
#      'name': 'Burrito Boyz'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 320,
#    'geocodes': {'main': {'latitude': 43.255691, 'longitude': -79.867215},
#     'roof': {'latitude': 43.255691, 'longitude': -79.867215}},
#    'link': '/v3/places/50a19225e4b035e940520491',
#    'location': {'address': '66 King St E',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '66 King St E, Hamilton ON L8N 1A6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1A6',
#     'region': 'ON'},
#    'name': 'Burrito Boyz',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '55de230f498eecf46f6652a2',
#    'categories': [{'id': 13306,
#      'name': 'Taco Restaurant',
#      'short_name': 'Tacos',
#      'plural_name': 'Taco Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 343,
#    'geocodes': {'drop_off': {'latitude': 43.257143, 'longitude': -79.86724},
#     'main': {'latitude': 43.257258, 'longitude': -79.867202},
#     'roof': {'latitude': 43.257258, 'longitude': -79.867202}},
#    'link': '/v3/places/55de230f498eecf46f6652a2',
#    'location': {'address': '41 King William St',
#     'country': 'CA',
#     'cross_street': 'Hughson',
#     'formatted_address': '41 King William St (Hughson), Hamilton ON L8R 1A2',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 1A2',
#     'region': 'ON'},
#    'name': 'The Mule',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b628f4bf964a5205a4b2ae3',
#    'categories': [{'id': 17065,
#      'name': 'Farmers Market',
#      'short_name': 'Farmers Market',
#      'plural_name': 'Farmers Markets',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#       'suffix': '.png'}},
#     {'id': 17069,
#      'name': 'Grocery Store',
#      'short_name': 'Grocery Store',
#      'plural_name': 'Grocery Stores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 395,
#    'geocodes': {'main': {'latitude': 43.259041, 'longitude': -79.870193},
#     'roof': {'latitude': 43.259041, 'longitude': -79.870193}},
#    'link': '/v3/places/4b628f4bf964a5205a4b2ae3',
#    'location': {'address': '55 York Blvd',
#     'country': 'CA',
#     'cross_street': 'at James',
#     'formatted_address': '55 York Blvd (at James), Hamilton ON L8R 3K1',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 3K1',
#     'region': 'ON'},
#    'name': "Hamilton Farmers' Market",
#    'related_places': {'children': [{'fsq_id': '5d7bd06979bb820008173f0e',
#       'categories': [{'id': 13026,
#         'name': 'BBQ Joint',
#         'short_name': 'BBQ',
#         'plural_name': 'BBQ Joints',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#          'suffix': '.png'}}],
#       'name': 'Saltlick Smokehouse'}]},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '511d7162e4b084a5d1f26958',
#    'categories': [{'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 357,
#    'geocodes': {'drop_off': {'latitude': 43.25803, 'longitude': -79.873899},
#     'main': {'latitude': 43.2582, 'longitude': -79.873853},
#     'roof': {'latitude': 43.2582, 'longitude': -79.873853}},
#    'link': '/v3/places/511d7162e4b084a5d1f26958',
#    'location': {'address': '152 King St W',
#     'country': 'CA',
#     'cross_street': 'Bay And King',
#     'formatted_address': '152 King St W (Bay And King), Hamilton ON L8P 1A5',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1A5',
#     'region': 'ON'},
#    'name': 'The George Hamilton',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b5e5923f964a520b78a29e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13031,
#      'name': 'Burger Joint',
#      'short_name': 'Burgers',
#      'plural_name': 'Burger Joints',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'}},
#     {'id': 13338,
#      'name': 'Seafood Restaurant',
#      'short_name': 'Seafood',
#      'plural_name': 'Seafood Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 409,
#    'geocodes': {'drop_off': {'latitude': 43.251943, 'longitude': -79.870017},
#     'main': {'latitude': 43.252066, 'longitude': -79.869987},
#     'roof': {'latitude': 43.252066, 'longitude': -79.869987}},
#    'link': '/v3/places/4b5e5923f964a520b78a29e3',
#    'location': {'address': '23 Augusta St',
#     'country': 'CA',
#     'cross_street': 'Hughson St.',
#     'formatted_address': '23 Augusta St (Hughson St.), Hamilton ON L8N 1P6',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P6',
#     'region': 'ON'},
#    'name': 'The Ship',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b01f834f964a520e64622e3',
#    'categories': [{'id': 13018,
#      'name': 'Pub',
#      'short_name': 'Pub',
#      'plural_name': 'Pubs',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 420,
#    'geocodes': {'drop_off': {'latitude': 43.252037, 'longitude': -79.870397},
#     'main': {'latitude': 43.25192, 'longitude': -79.870426},
#     'roof': {'latitude': 43.25192, 'longitude': -79.870426}},
#    'link': '/v3/places/4b01f834f964a520e64622e3',
#    'location': {'address': '20 Augusta St',
#     'country': 'CA',
#     'cross_street': 'James St.',
#     'formatted_address': '20 Augusta St (James St.), Hamilton ON L8N 1P7',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 1P7',
#     'region': 'ON'},
#    'name': 'The Pheasant Plucker',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4b6a4bc5f964a52024d12be3',
#    'categories': [{'id': 13068,
#      'name': 'American Restaurant',
#      'short_name': 'American',
#      'plural_name': 'American Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13134,
#      'name': 'Comfort Food Restaurant',
#      'short_name': 'Comfort Food',
#      'plural_name': 'Comfort Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 436,
#    'geocodes': {'main': {'latitude': 43.251462, 'longitude': -79.872017},
#     'roof': {'latitude': 43.251462, 'longitude': -79.872017}},
#    'link': '/v3/places/4b6a4bc5f964a52024d12be3',
#    'location': {'address': '1 Duke St',
#     'country': 'CA',
#     'cross_street': 'at James St. South',
#     'formatted_address': '1 Duke St (at James St. South), Hamilton ON L8P 1W9',
#     'locality': 'Hamilton',
#     'postcode': 'L8P 1W9',
#     'region': 'ON'},
#    'name': 'One Duke Restaurant & Lounge',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '591534a12aff31013acefff6',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13029,
#      'name': 'Brewery',
#      'short_name': 'Brewery',
#      'plural_name': 'Breweries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 491,
#    'geocodes': {'main': {'latitude': 43.25949, 'longitude': -79.867997},
#     'roof': {'latitude': 43.25949, 'longitude': -79.867997}},
#    'link': '/v3/places/591534a12aff31013acefff6',
#    'location': {'address': '107 James St N',
#     'country': 'CA',
#     'cross_street': 'at York Blvd',
#     'formatted_address': '107 James St N (at York Blvd), Hamilton ON L8R 2K6',
#     'locality': 'Hamilton',
#     'postcode': 'L8R 2K6',
#     'region': 'ON'},
#    'name': 'Merit Brewing',
#    'related_places': {},
#    'timezone': 'America/Toronto'},
#   {'fsq_id': '4cb0ca4baef16dcbc327b454',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'short_name': 'Diner',
#      'plural_name': 'Diners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}},
#     {'id': 13072,
#      'name': 'Asian Restaurant',
#      'short_name': 'Asian',
#      'plural_name': 'Asian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 517,
#    'geocodes': {'main': {'latitude': 43.254244, 'longitude': -79.865672},
#     'roof': {'latitude': 43.254244, 'longitude': -79.865672}},
#    'link': '/v3/places/4cb0ca4baef16dcbc327b454',
#    'location': {'address': '100 Main St E',
#     'address_extended': '# 100',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '100 Main St E, Hamilton ON L8N 3W4',
#     'locality': 'Hamilton',
#     'postcode': 'L8N 3W4',
#     'region': 'ON'},
#    'name': 'Tea Hut',
#    'related_places': {},
#    'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.2557,
#      'longitude': -79.8711},
#     'radius': 1000}}}}

# %%
test
# Out:
# {'businesses': [{'id': '752Fv2jKafftvoS3Twkqyg',
#    'alias': 'hambrgr-hamilton',
#    'name': 'Hambrgr',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 207,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['49 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893891212',
#    'display_phone': '+1 289-389-1212',
#    'distance': 377.3430524726985,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://hambrgr.ca/menu-king-william',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'bHecMQ85o3ayw1t9hRA90g',
#    'alias': 'the-french-hamilton',
#    'name': 'The French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 100,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.25741, 'longitude': -79.86748},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['37 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055283737',
#    'display_phone': '+1 905-528-3737',
#    'distance': 351.909786169935,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.thefrench.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 181,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
#    'display_phone': '+1 289-389-2555',
#    'distance': 355.3118981187424,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '9oIPWjU3DvtSdORv6I2toQ',
#    'alias': 'the-ship-hamilton',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 208,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.25215, 'longitude': -79.87},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Augusta Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1P6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Augusta Street',
#      'Hamilton, ON L8N 1P6',
#      'Canada']},
#    'phone': '+19055260792',
#    'display_phone': '+1 905-526-0792',
#    'distance': 404.5078559430542,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.theship.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'xwVB61hW9rpyp6wALR4Apg',
#    'alias': 'berkeley-north-hamilton-2',
#    'name': 'Berkeley North',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 41,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.2574045478956,
#     'longitude': -79.8677145254958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '31 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['31 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055225858',
#    'display_phone': '+1 905-522-5858',
#    'distance': 333.3015970930127,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.berkeleynorth.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'PAVNadox4HMXl-xdsjbjhg',
#    'alias': 'sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton',
#    'name': 'Sagarmatha Curry Palace  Authentic Indian & Nepalese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sRLHpiBxJLpybfnuu0YROw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 41,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.25725, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055226999',
#    'display_phone': '+1 905-522-6999',
#    'distance': 367.90830605891756,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://sagarmathacurrypalace.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'wZr3xBFhGfYMY-mqwsQuNQ',
#    'alias': 'redchurch-cafe-gallery-hamilton',
#    'name': 'Redchurch Cafe + Gallery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qua9YE4kD7B3zl22UxtJLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redchurch-cafe-gallery-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 26,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25551, 'longitude': -79.86725},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['68 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19054070459',
#    'display_phone': '+1 905-407-0459',
#    'distance': 307.9264546303288,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.redchurchcafe.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'zldX2jhIDUBJzaEPYiSWUQ',
#    'alias': 'radius-hamilton',
#    'name': 'Radius',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9bd_uf5aVnJgtJOFA8BNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radius-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 94,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.2523512, 'longitude': -79.8708333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '151 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 2Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['151 James Street S',
#      'Hamilton, ON L8P 2Z5',
#      'Canada']},
#    'phone': '+19053931658',
#    'display_phone': '+1 905-393-1658',
#    'distance': 372.9950420410887,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://radius.ca/food-menus',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'EGutBSi1dgdaJoLu-LdsTw',
#    'alias': 'august-8-hamilton',
#    'name': 'August 8',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HAndOnz4E-AIgQSaRJTwkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/august-8-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 124,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25943, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Wilson Street',
#     'address2': 'Suite 12',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1 Wilson Street',
#      'Suite 12',
#      'Hamilton, ON L8R',
#      'Canada']},
#    'phone': '+19055243838',
#    'display_phone': '+1 905-524-3838',
#    'distance': 530.3493444139274,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Cg0WEknzjnguRylTcf1pEQ',
#    'alias': 'kenzo-hamilton',
#    'name': 'Kenzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbxtzsWRIMnxlBbjL-AZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenzo-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 24,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.256548097485,
#     'longitude': -79.8681968450546},
#    'transactions': [],
#    'location': {'address1': '21 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['21 King Street E', 'Hamilton, ON L8N 1A1', 'Canada']},
#    'phone': '+19055776666',
#    'display_phone': '+1 905-577-6666',
#    'distance': 253.31417087303663,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'OQvZPynueXmDp4H5fqWT_w',
#    'alias': 'undefined-hamilton',
#    'name': 'Undefined',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBmKwmOBRGvEjn62TIIoDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/undefined-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 9,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.25743, 'longitude': -79.86754},
#    'transactions': [],
#    'location': {'address1': '35 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['35 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19053938343',
#    'display_phone': '+1 905-393-8343',
#    'distance': 343.38385478879684,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.eatundefined.com/#menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'F62oIPt7-CwuYHJ6vXp-HQ',
#    'alias': 'black-forest-inn-european-cuisine-hamilton',
#    'name': 'Black Forest Inn European Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EuO8QZ62njCuZr2_jrHMTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-inn-european-cuisine-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 53,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2543558198212,
#     'longitude': -79.8615892650853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '255 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1B9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['255 King Street E',
#      'Hamilton, ON L8N 1B9',
#      'Canada']},
#    'phone': '+19055283538',
#    'display_phone': '+1 905-528-3538',
#    'distance': 784.5893139940273,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '_Tl4-DH2ci_AVXq028__sg',
#    'alias': 'burrito-boyz-hamilton',
#    'name': 'Burrito Boyz',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p3C2_MKwb12bVWqaWjQLNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrito-boyz-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2557373046875,
#     'longitude': -79.8669128417969},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['66 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19055292699',
#    'display_phone': '+1 905-529-2699',
#    'distance': 339.11593791205866,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'JPsfA7czh0PusUKqpduDUA',
#    'alias': 'ajio-sushi-hamilton',
#    'name': 'Ajio Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IhDS5NyrOffNTSXy0FFckQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajio-sushi-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 43,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.21798, 'longitude': -79.74587},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '161 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1J6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['161 King Street E',
#      'Hamilton, ON L8R 1J6',
#      'Canada']},
#    'phone': '+19055268888',
#    'display_phone': '+1 905-526-8888',
#    'distance': 554.3762050519049,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.ajiosushikorea.com/main-dish3',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'XYZirPf2pYh4BAHb9GbtVA',
#    'alias': 'diplomat-hamilton',
#    'name': 'Diplomat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxoasGf51kBqhL3l4g-kSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diplomat-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 23,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.2572440040624,
#     'longitude': -79.8670820519328},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '43 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055234343',
#    'display_phone': '+1 905-523-4343',
#    'distance': 367.8996083353947,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://thediplomat.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'CH4A4Aa--t0A7bP1VfkMrA',
#    'alias': 'charred-chicken-hamilton',
#    'name': 'Charred Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agEtNIDjFHSHuMTjDKhipQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 117,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.2627364, 'longitude': -79.8663839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '244 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['244 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893960662',
#    'display_phone': '+1 289-396-0662',
#    'distance': 870.6422541964347,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'GTAJyJuT_sE0byRLTdM5sA',
#    'alias': 'sapporo-japanese-restaurant-hamilton',
#    'name': 'Sapporo Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aAgDdX7jF567YOHXJahCrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapporo-japanese-restaurant-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 91,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 43.25429, 'longitude': -79.866},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Main St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Main St E', 'Hamilton, ON L8N 1G3', 'Canada']},
#    'phone': '+19055271668',
#    'display_phone': '+1 905-527-1668',
#    'distance': 434.6251594021986,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'vqyK2q3zJ74TIT1-7Bf3Tg',
#    'alias': 'la-luna-hamilton',
#    'name': 'La Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 66,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.25942165323912,
#     'longitude': -79.87848757635106},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '306 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['306 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19055770233',
#    'display_phone': '+1 905-577-0233',
#    'distance': 727.4346491267174,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'xUy8292rGVB_picXiGeQoQ',
#    'alias': 'bronzies-place-hamilton',
#    'name': "Bronzie's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sve9rY2YfBDzEQw5TmQ2hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronzies-place-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 28,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.2505499, 'longitude': -79.87143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '201 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3A8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['201 James Street S',
#      'Hamilton, ON L8P 3A8',
#      'Canada']},
#    'phone': '+19055293403',
#    'display_phone': '+1 905-529-3403',
#    'distance': 572.2718725723605,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://bronzies.ca/lunch-dinner-menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'TxrfCuyQThzsFUlcFqdqSw',
#    'alias': 'saint-james-espresso-bar-and-eatery-hamilton-2',
#    'name': 'Saint James Espresso Bar & Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 57,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.26098, 'longitude': -79.86693},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 James Street N',
#      'Hamilton, ON L8R 2L1',
#      'Canada']},
#    'phone': '+12893896565',
#    'display_phone': '+1 289-389-6565',
#    'distance': 679.8258228780344,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 223,
#  'region': {'center': {'longitude': -79.8711, 'latitude': 43.2557}}}

# %%
foursquarebiketracking=pd.DataFrame()
import json
for index, row in available_bikes.iterrows():
    ll = (row['Latitude'], row['Longitude'])
    foursquarebiketracking['Station Name']=row ['Station Name']
    response = get_nearby_venues(ll, 1000, None)
    foursquarebiketracking.loc[index,'newcolumn']=json.dumps(response)

# %%
foursquarebiketracking
# Out:
#            Station Name                                          newcolumn
# 0    Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 1    Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 2    Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 3    Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 4    Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# ..                  ...                                                ...
# 140  Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 141  Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 142  Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 143  Van Wagner's Beach  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
# 144                 NaN  {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg...
#
# [145 rows x 2 columns]

# %%
venues=json.loads(foursquarebiketracking['newcolumn'][0])
flattenedvenue=pd.json_normalize(venues['results'])
flattenedvenue.head(2)
flattenedvenue.columns
# Out:
# Index(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'link',
#        'name', 'timezone', 'geocodes.main.latitude', 'geocodes.main.longitude',
#        'geocodes.roof.latitude', 'geocodes.roof.longitude', 'location.address',
#        'location.country', 'location.formatted_address', 'location.locality',
#        'location.postcode', 'location.region', 'location.cross_street',
#        'geocodes.drop_off.latitude', 'geocodes.drop_off.longitude',
#        'related_places.children', 'location.address_extended'],
#       dtype='object')

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
flatteneddata=pd.DataFrame()
for index, row in foursquarebiketracking.iterrows():
    venues=json.loads (row['newcolumn'])
    flattenedvenue=pd.json_normalize (venues['results'])
    flattenedvenue['Station Name']=row['Station Name']
    flatteneddata=pd.concat([flatteneddata,flattenedvenue],ignore_index=True)
flatteneddata.head()
# Out:
#                      fsq_id  \
# 0  4d93318162ad5481a9ec7b4b
# 1  50a19225e4b035e940520491
# 2  55de230f498eecf46f6652a2
# 3  4b628f4bf964a5205a4b2ae3
# 4  511d7162e4b084a5d1f26958
#
#                                           categories  \
# 0  [{'id': 10027, 'name': 'Museum', 'short_name':...
# 1  [{'id': 13305, 'name': 'Burrito Restaurant', '...
# 2  [{'id': 13306, 'name': 'Taco Restaurant', 'sho...
# 3  [{'id': 17065, 'name': 'Farmers Market', 'shor...
# 4  [{'id': 13065, 'name': 'Restaurant', 'short_na...
#
#                                               chains   closed_bucket  \
# 0                                                 []  VeryLikelyOpen
# 1  [{'id': '2d108fae-d80a-482b-a105-57ab79c2581e'...  VeryLikelyOpen
# 2                                                 []  VeryLikelyOpen
# 3                                                 []      LikelyOpen
# 4                                                 []  VeryLikelyOpen
#
#    distance                                 link  \
# 0       172  /v3/places/4d93318162ad5481a9ec7b4b
# 1       320  /v3/places/50a19225e4b035e940520491
# 2       343  /v3/places/55de230f498eecf46f6652a2
# 3       395  /v3/places/4b628f4bf964a5205a4b2ae3
# 4       357  /v3/places/511d7162e4b084a5d1f26958
#
#                                   name         timezone  \
# 0  Whitehern Historic House and Garden  America/Toronto
# 1                         Burrito Boyz  America/Toronto
# 2                             The Mule  America/Toronto
# 3             Hamilton Farmers' Market  America/Toronto
# 4                  The George Hamilton  America/Toronto
#
#    geocodes.main.latitude  geocodes.main.longitude  ...  \
# 0               43.254593               -79.872110  ...
# 1               43.255691               -79.867215  ...
# 2               43.257258               -79.867202  ...
# 3               43.259041               -79.870193  ...
# 4               43.258200               -79.873853  ...
#
#                           location.formatted_address  location.locality  \
# 0               41 Jackson St W, Hamilton ON L8P 1L3           Hamilton
# 1                  66 King St E, Hamilton ON L8N 1A6           Hamilton
# 2  41 King William St (Hughson), Hamilton ON L8R 1A2           Hamilton
# 3       55 York Blvd (at James), Hamilton ON L8R 3K1           Hamilton
# 4  152 King St W (Bay And King), Hamilton ON L8P 1A5           Hamilton
#
#   location.postcode location.region location.cross_street  \
# 0           L8P 1L3              ON                   NaN
# 1           L8N 1A6              ON
# 2           L8R 1A2              ON               Hughson
# 3           L8R 3K1              ON              at James
# 4           L8P 1A5              ON          Bay And King
#
#   geocodes.drop_off.latitude geocodes.drop_off.longitude  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                  43.257143                  -79.867240
# 3                        NaN                         NaN
# 4                  43.258030                  -79.873899
#
#                              related_places.children  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'fsq_id': '5d7bd06979bb820008173f0e', 'categ...
# 4                                                NaN
#
#   location.address_extended    Station Name
# 0                       NaN  Cannon at East
# 1                       NaN  Cannon at East
# 2                       NaN  Cannon at East
# 3                       NaN  Cannon at East
# 4                       NaN  Cannon at East
#
# [5 rows x 24 columns]

# %%
flatteneddata.to_csv('..\\data\\flattenedfoursquaredata.csv', index=False)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests

# Define the function to get venues from Yelp
def get_venues_yelp(latitude, longitude, radius, api_key, categories=None):
    
    # Create the URL
    url = "https://api.yelp.com/v3/businesses/search"
    
    # Create the parameters
    params = {
        "latitude": latitude,
        "longitude": longitude,
        "radius": radius
    }
    
    # If categories are provided, add them to the parameters
    if categories:
        params["categories"] = categories
    
    # Create the headers with the correct authorization format
    headers = {
        "Authorization": f"Bearer {api_key}"
    }
    
    try:
        # Send the GET request to Yelp API
        response = requests.get(url, params=params, headers=headers)
        
        # Check the response status code
        print(response.status_code)
        
        # Return the response
        return response
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
latitude = 43.2557
longitude = -79.8711
radius = 1000  # in meters
api_key = "hVV22ajvn0URrv13vqyEHqcvVNfUu7cNzfh2EVolQ55AKt2I7pI82ITKTHa2cvVqsFPPRlexP0TO29cn1GWZGhsu7_n5ZcnSUPaWV7hSPJz-vB8133SA5aatHNAgZnYx"
categories = "bikestations"  # Specify the Yelp-recognized place types (e.g., "bikestations")

# Call the function to get venues from Yelp
response = get_venues_yelp(latitude, longitude, radius, api_key, categories)

# Check the response status code
print(response.status_code)

# Print the response text
print(response.text)
# Out:
# 429
# 429
# {"error": {"code": "ACCESS_LIMIT_REACHED", "description": "You've reached the access limit for this client. See instructions for requesting a higher access limit at https://docs.developer.yelp.com/docs/fusion-rate-limiting"}}

# %%
import pandas as pd

# %%
available_bikes_yelp=pd.read_csv('..\\data\\available_bikes.csv')

# %%
available_bikes_yelp
# Out:
#            Station Name   Latitude  Longitude  Bikes Available
# 0          Hess at king  43.259126 -79.877212                4
# 1         Bayfront Park  43.269288 -79.871327               13
# 2       Bay at Strachan  43.267859 -79.867923                3
# 3       Bay at Mulberry  43.263198 -79.871803                6
# 4             City Hall  43.256132 -79.874499                0
# ..                  ...        ...        ...              ...
# 140     Westdale Aviary  43.264869 -79.907480                3
# 141    Hunter GO Centre  43.253330 -79.869533                5
# 142    Westdale Village  43.262015 -79.905088               25
# 143    Cannon at Ottawa  43.247565 -79.818050                3
# 144  Van Wagner's Beach  43.260008 -79.766388                8
#
# [145 rows x 4 columns]

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?latitude=43.2557&longitude=-79.8711"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer hVV22ajvn0URrv13vqyEHqcvVNfUu7cNzfh2EVolQ55AKt2I7pI82ITKTHa2cvVqsFPPRlexP0TO29cn1GWZGhsu7_n5ZcnSUPaWV7hSPJz-vB8133SA5aatHNAgZnYx"
}

response = requests.get(url, headers=headers)

print(response.text)

# Define category IDs for bike-related venues
bike_rental_category_id = '4e4c9077bd41f78e849722f9'  # Bike rental / bike shop category ID
# Out:
# {"businesses": [{"id": "752Fv2jKafftvoS3Twkqyg", "alias": "hambrgr-hamilton", "name": "Hambrgr", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg", "review_count": 207, "categories": [{"alias": "burgers", "title": "Burgers"}, {"alias": "beerbar", "title": "Beer Bar"}], "rating": 4.3, "coordinates": {"latitude": 43.25721, "longitude": -79.8669}, "transactions": [], "price": "$$", "location": {"address1": "49 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["49 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893891212", "display_phone": "+1 289-389-1212", "distance": 377.3430524726985, "attributes": {"business_temp_closed": null, "menu_url": "http://hambrgr.ca/menu-king-william", "open24_hours": null, "waitlist_reservation": null}}, {"id": "9oIPWjU3DvtSdORv6I2toQ", "alias": "the-ship-hamilton", "name": "The Ship", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg", "review_count": 208, "categories": [{"alias": "seafood", "title": "Seafood"}, {"alias": "pubs", "title": "Pubs"}, {"alias": "burgers", "title": "Burgers"}], "rating": 4.1, "coordinates": {"latitude": 43.25215, "longitude": -79.87}, "transactions": [], "price": "$$", "location": {"address1": "23 Augusta Street", "address2": "", "address3": "", "city": "Hamilton", "zip_code": "L8N 1P6", "country": "CA", "state": "ON", "display_address": ["23 Augusta Street", "Hamilton, ON L8N 1P6", "Canada"]}, "phone": "+19055260792", "display_phone": "+1 905-526-0792", "distance": 404.5078559430542, "attributes": {"business_temp_closed": null, "menu_url": "http://www.theship.ca/menu/", "open24_hours": null, "waitlist_reservation": null}}, {"id": "h2mI1wBIK1PyaNupaL58gw", "alias": "the-mule-hamilton", "name": "The Mule", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg", "review_count": 181, "categories": [{"alias": "mexican", "title": "Mexican"}], "rating": 3.9, "coordinates": {"latitude": 43.25726, "longitude": -79.86713}, "transactions": [], "price": "$$", "location": {"address1": "41 King William Street", "address2": null, "address3": "", "city": "Hamilton", "zip_code": "L8R 1A2", "country": "CA", "state": "ON", "display_address": ["41 King William Street", "Hamilton, ON L8R 1A2", "Canada"]}, "phone": "+12893892555", "display_phone": "+1 289-389-2555", "distance": 355.3118981187424, "attributes": {"business_temp_closed": null, "menu_url": null, "open24_hours": null, "waitlist_reservation": null}}, {"id": "bHecMQ85o3ayw1t9hRA90g", "alias": "the-french-hamilton", "name": "The French", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-french-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg", "review_count": 100, "categories": [{"alias": "bistros", "title": "Bistros"}, {"alias": "french", "title": "French"}], "rating": 4.2, "coordinates": {"latitude": 43.25741, "longitude": -79.86748}, "transactions": [], "price": "$$$", "location": {"address1": "37 King William Street", "address2": "", "address3": null, "city": "Hamilton", "zip_code": "L8R 1A1", "country": "CA", "state": "ON", "dis ...

# %%
# Function to query yelp API for venues near a given location
def get_nearby_venues(ll, radius, category_id):
    params = {
        # 'client_id': CLIENT_ID,
        # 'client_secret': CLIENT_SECRET,
        # 'v': VERSION,
        'll': ll,
        'radius': radius,
        'categoryId': category_id
    }
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer hVV22ajvn0URrv13vqyEHqcvVNfUu7cNzfh2EVolQ55AKt2I7pI82ITKTHa2cvVqsFPPRlexP0TO29cn1GWZGhsu7_n5ZcnSUPaWV7hSPJz-vB8133SA5aatHNAgZnYx"
}
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
       # return response.json()['response']['venues']
        return response.json()
    else:
        print(f'Error: {response.status_code} - {response.text}')
        return None

# %%
test=get_nearby_venues ((43.2557,-79.8711), 1000, None)

# %%
test
# Out:
# {'businesses': [{'id': '752Fv2jKafftvoS3Twkqyg',
#    'alias': 'hambrgr-hamilton',
#    'name': 'Hambrgr',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3QVAocW1I5_XTniJy_A7xA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hambrgr-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 207,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.25721, 'longitude': -79.8669},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['49 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893891212',
#    'display_phone': '+1 289-389-1212',
#    'distance': 377.3430524726985,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://hambrgr.ca/menu-king-william',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'bHecMQ85o3ayw1t9hRA90g',
#    'alias': 'the-french-hamilton',
#    'name': 'The French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ha71dfKKkDf9S75w8TTg3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-french-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 100,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.25741, 'longitude': -79.86748},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '37 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['37 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055283737',
#    'display_phone': '+1 905-528-3737',
#    'distance': 351.909786169935,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.thefrench.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'h2mI1wBIK1PyaNupaL58gw',
#    'alias': 'the-mule-hamilton',
#    'name': 'The Mule',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnnLUscVQbblKXi2eVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mule-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 181,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25726, 'longitude': -79.86713},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['41 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+12893892555',
#    'display_phone': '+1 289-389-2555',
#    'distance': 355.3118981187424,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '9oIPWjU3DvtSdORv6I2toQ',
#    'alias': 'the-ship-hamilton',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA72m1IJKIKIVjk4UTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 208,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.25215, 'longitude': -79.87},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23 Augusta Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1P6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['23 Augusta Street',
#      'Hamilton, ON L8N 1P6',
#      'Canada']},
#    'phone': '+19055260792',
#    'display_phone': '+1 905-526-0792',
#    'distance': 404.5078559430542,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.theship.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'xwVB61hW9rpyp6wALR4Apg',
#    'alias': 'berkeley-north-hamilton-2',
#    'name': 'Berkeley North',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dR82KlG7oA71lWXG2z7HzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-north-hamilton-2?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 41,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.2574045478956,
#     'longitude': -79.8677145254958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '31 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['31 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19055225858',
#    'display_phone': '+1 905-522-5858',
#    'distance': 333.3015970930127,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.berkeleynorth.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'PAVNadox4HMXl-xdsjbjhg',
#    'alias': 'sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton',
#    'name': 'Sagarmatha Curry Palace  Authentic Indian & Nepalese Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sRLHpiBxJLpybfnuu0YROw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sagarmatha-curry-palace-authentic-indian-and-nepalese-cuisine-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 41,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.25725, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43 King William Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055226999',
#    'display_phone': '+1 905-522-6999',
#    'distance': 367.90830605891756,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://sagarmathacurrypalace.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'wZr3xBFhGfYMY-mqwsQuNQ',
#    'alias': 'redchurch-cafe-gallery-hamilton',
#    'name': 'Redchurch Cafe + Gallery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qua9YE4kD7B3zl22UxtJLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/redchurch-cafe-gallery-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 26,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.25551, 'longitude': -79.86725},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '68 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['68 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19054070459',
#    'display_phone': '+1 905-407-0459',
#    'distance': 307.9264546303288,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.redchurchcafe.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'zldX2jhIDUBJzaEPYiSWUQ',
#    'alias': 'radius-hamilton',
#    'name': 'Radius',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9bd_uf5aVnJgtJOFA8BNpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/radius-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 94,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.2523512, 'longitude': -79.8708333},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '151 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 2Z5',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['151 James Street S',
#      'Hamilton, ON L8P 2Z5',
#      'Canada']},
#    'phone': '+19053931658',
#    'display_phone': '+1 905-393-1658',
#    'distance': 372.9950420410887,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://radius.ca/food-menus',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'EGutBSi1dgdaJoLu-LdsTw',
#    'alias': 'august-8-hamilton',
#    'name': 'August 8',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HAndOnz4E-AIgQSaRJTwkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/august-8-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 124,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.25943, 'longitude': -79.86708},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Wilson Street',
#     'address2': 'Suite 12',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['1 Wilson Street',
#      'Suite 12',
#      'Hamilton, ON L8R',
#      'Canada']},
#    'phone': '+19055243838',
#    'display_phone': '+1 905-524-3838',
#    'distance': 530.3493444139274,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Cg0WEknzjnguRylTcf1pEQ',
#    'alias': 'kenzo-hamilton',
#    'name': 'Kenzo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rbxtzsWRIMnxlBbjL-AZfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kenzo-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 24,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.256548097485,
#     'longitude': -79.8681968450546},
#    'transactions': [],
#    'location': {'address1': '21 King Street E',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['21 King Street E', 'Hamilton, ON L8N 1A1', 'Canada']},
#    'phone': '+19055776666',
#    'display_phone': '+1 905-577-6666',
#    'distance': 253.31417087303663,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'OQvZPynueXmDp4H5fqWT_w',
#    'alias': 'undefined-hamilton',
#    'name': 'Undefined',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBmKwmOBRGvEjn62TIIoDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/undefined-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 9,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.25743, 'longitude': -79.86754},
#    'transactions': [],
#    'location': {'address1': '35 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['35 King William Street',
#      'Hamilton, ON L8R 1A1',
#      'Canada']},
#    'phone': '+19053938343',
#    'display_phone': '+1 905-393-8343',
#    'distance': 343.38385478879684,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.eatundefined.com/#menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'F62oIPt7-CwuYHJ6vXp-HQ',
#    'alias': 'black-forest-inn-european-cuisine-hamilton',
#    'name': 'Black Forest Inn European Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EuO8QZ62njCuZr2_jrHMTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-forest-inn-european-cuisine-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 53,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2543558198212,
#     'longitude': -79.8615892650853},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '255 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1B9',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['255 King Street E',
#      'Hamilton, ON L8N 1B9',
#      'Canada']},
#    'phone': '+19055283538',
#    'display_phone': '+1 905-528-3538',
#    'distance': 784.5893139940273,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '_Tl4-DH2ci_AVXq028__sg',
#    'alias': 'burrito-boyz-hamilton',
#    'name': 'Burrito Boyz',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p3C2_MKwb12bVWqaWjQLNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burrito-boyz-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 45,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.2557373046875,
#     'longitude': -79.8669128417969},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1A6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['66 King Street E', 'Hamilton, ON L8N 1A6', 'Canada']},
#    'phone': '+19055292699',
#    'display_phone': '+1 905-529-2699',
#    'distance': 339.11593791205866,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'JPsfA7czh0PusUKqpduDUA',
#    'alias': 'ajio-sushi-hamilton',
#    'name': 'Ajio Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IhDS5NyrOffNTSXy0FFckQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajio-sushi-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 43,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.21798, 'longitude': -79.74587},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '161 King Street E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1J6',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['161 King Street E',
#      'Hamilton, ON L8R 1J6',
#      'Canada']},
#    'phone': '+19055268888',
#    'display_phone': '+1 905-526-8888',
#    'distance': 554.3762050519049,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.ajiosushikorea.com/main-dish3',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'XYZirPf2pYh4BAHb9GbtVA',
#    'alias': 'diplomat-hamilton',
#    'name': 'Diplomat',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxoasGf51kBqhL3l4g-kSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diplomat-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 23,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.2572440040624,
#     'longitude': -79.8670820519328},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '43 King William Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Hamilton',
#     'zip_code': 'L8R 1A2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['43 King William Street',
#      'Hamilton, ON L8R 1A2',
#      'Canada']},
#    'phone': '+19055234343',
#    'display_phone': '+1 905-523-4343',
#    'distance': 367.8996083353947,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://thediplomat.ca/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'CH4A4Aa--t0A7bP1VfkMrA',
#    'alias': 'charred-chicken-hamilton',
#    'name': 'Charred Chicken',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/agEtNIDjFHSHuMTjDKhipQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charred-chicken-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 117,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.2627364, 'longitude': -79.8663839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '244 James Street N',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L2',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['244 James Street N',
#      'Hamilton, ON L8R 2L2',
#      'Canada']},
#    'phone': '+12893960662',
#    'display_phone': '+1 289-396-0662',
#    'distance': 870.6422541964347,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'GTAJyJuT_sE0byRLTdM5sA',
#    'alias': 'sapporo-japanese-restaurant-hamilton',
#    'name': 'Sapporo Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aAgDdX7jF567YOHXJahCrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sapporo-japanese-restaurant-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 91,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 43.25429, 'longitude': -79.866},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '96 Main St E',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8N 1G3',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['96 Main St E', 'Hamilton, ON L8N 1G3', 'Canada']},
#    'phone': '+19055271668',
#    'display_phone': '+1 905-527-1668',
#    'distance': 434.6251594021986,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'vqyK2q3zJ74TIT1-7Bf3Tg',
#    'alias': 'la-luna-hamilton',
#    'name': 'La Luna',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OBRpyj_wUqmDwKLtKU4pCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-luna-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 66,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.25942165323912,
#     'longitude': -79.87848757635106},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '306 King Street W',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 1B1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['306 King Street W',
#      'Hamilton, ON L8P 1B1',
#      'Canada']},
#    'phone': '+19055770233',
#    'display_phone': '+1 905-577-0233',
#    'distance': 727.4346491267174,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'xUy8292rGVB_picXiGeQoQ',
#    'alias': 'bronzies-place-hamilton',
#    'name': "Bronzie's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Sve9rY2YfBDzEQw5TmQ2hA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bronzies-place-hamilton?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 28,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.2505499, 'longitude': -79.87143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '201 James Street S',
#     'address2': '',
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8P 3A8',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['201 James Street S',
#      'Hamilton, ON L8P 3A8',
#      'Canada']},
#    'phone': '+19055293403',
#    'display_phone': '+1 905-529-3403',
#    'distance': 572.2718725723605,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://bronzies.ca/lunch-dinner-menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'TxrfCuyQThzsFUlcFqdqSw',
#    'alias': 'saint-james-espresso-bar-and-eatery-hamilton-2',
#    'name': 'Saint James Espresso Bar & Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-T6LAsL5n5Sa-EyW5vDq7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-james-espresso-bar-and-eatery-hamilton-2?adjust_creative=fRkw3HzayIJbOk3kT27ATg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fRkw3HzayIJbOk3kT27ATg',
#    'review_count': 57,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.26098, 'longitude': -79.86693},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '170 James Street N',
#     'address2': None,
#     'address3': '',
#     'city': 'Hamilton',
#     'zip_code': 'L8R 2L1',
#     'country': 'CA',
#     'state': 'ON',
#     'display_address': ['170 James Street N',
#      'Hamilton, ON L8R 2L1',
#      'Canada']},
#    'phone': '+12893896565',
#    'display_phone': '+1 289-389-6565',
#    'distance': 679.8258228780344,
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 223,
#  'region': {'center': {'longitude': -79.8711, 'latitude': 43.2557}}}

# %%
yelpbiketracking=pd.DataFrame()
import json
for index, row in available_bikes_yelp.iterrows():
    ll = (row['Latitude'], row['Longitude'])
    yelpbiketracking['Station Name']=row ['Station Name']
    response = get_nearby_venues(ll, 1000, None)
    yelpbiketracking.loc[index,'newcolumn']=json.dumps(response)

# %%
yelpbiketracking
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
venues=json.loads(yelpbiketracking['newcolumn'][0])
flattenedvenue=pd.json_normalize(venues['businesses'])
flattenedvenue.head(2)
flattenedvenue.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address',
#        'attributes.business_temp_closed', 'attributes.menu_url',
#        'attributes.open24_hours', 'attributes.waitlist_reservation'],
#       dtype='object')

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
import json
flatteneddata=pd.DataFrame()
for index, row in yelpbiketracking.iterrows():
    venues=json.loads (row['newcolumn'])
    flattenedvenue=pd.json_normalize (venues['businesses'])
    flattenedvenue['Station Name']=row['Station Name']
    flatteneddata=pd.concat([flatteneddata,flattenedvenue],ignore_index=True)
flatteneddata.head()
# Out:
#                        id                      alias            name  \
# 0  752Fv2jKafftvoS3Twkqyg           hambrgr-hamilton         Hambrgr
# 1  bHecMQ85o3ayw1t9hRA90g        the-french-hamilton      The French
# 2  h2mI1wBIK1PyaNupaL58gw          the-mule-hamilton        The Mule
# 3  9oIPWjU3DvtSdORv6I2toQ          the-ship-hamilton        The Ship
# 4  xwVB61hW9rpyp6wALR4Apg  berkeley-north-hamilton-2  Berkeley North
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/3QVAoc...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/Ha71df...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/bbhfnn...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/dvWeA7...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/dR82Kl...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/hambrgr-hamilton?adju...           207
# 1  https://www.yelp.com/biz/the-french-hamilton?a...           100
# 2  https://www.yelp.com/biz/the-mule-hamilton?adj...           181
# 3  https://www.yelp.com/biz/the-ship-hamilton?adj...           208
# 4  https://www.yelp.com/biz/berkeley-north-hamilt...            41
#
#                                           categories  rating transactions  \
# 0  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.3           []
# 1  [{'alias': 'bistros', 'title': 'Bistros'}, {'a...     4.2           []
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]     3.9           []
# 3  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.1           []
# 4  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.3           []
#
#    ... location.city location.zip_code location.country  location.state  \
# 0  ...      Hamilton           L8R 1A2               CA              ON
# 1  ...      Hamilton           L8R 1A1               CA              ON
# 2  ...      Hamilton           L8R 1A2               CA              ON
# 3  ...      Hamilton           L8N 1P6               CA              ON
# 4  ...      Hamilton           L8R 1A1               CA              ON
#
#                             location.display_address  \
# 0  [49 King William Street, Hamilton, ON L8R 1A2,...
# 1  [37 King William Street, Hamilton, ON L8R 1A1,...
# 2  [41 King William Street, Hamilton, ON L8R 1A2,...
# 3  [23 Augusta Street, Hamilton, ON L8N 1P6, Canada]
# 4  [31 King William Street, Hamilton, ON L8R 1A1,...
#
#    attributes.business_temp_closed                  attributes.menu_url  \
# 0                             None  http://hambrgr.ca/menu-king-william
# 1                             None        http://www.thefrench.ca/menu/
# 2                             None                                 None
# 3                             None          http://www.theship.ca/menu/
# 4                             None    http://www.berkeleynorth.ca/menu/
#
#   attributes.open24_hours attributes.waitlist_reservation        Station Name
# 0                    None                            None  Sanders at Binkley
# 1                    None                            None  Sanders at Binkley
# 2                    None                            None  Sanders at Binkley
# 3                    None                            None  Sanders at Binkley
# 4                    None                            None  Sanders at Binkley
#
# [5 rows x 29 columns]

# %%
flatteneddata.to_csv('..\\data\\flattenedYELPdata4.csv', index=False)

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
flattenedfoursquaredata = pd.read_csv('..\\data\\flattenedfoursquaredata.csv')

# Get the shape of the DataFrame
num_rows, num_columns = flattenedfoursquaredata.shape
print("Total rows:", num_rows)
print("Total columns:", num_columns)
# Out:
# Total rows: 1300
# Total columns: 24

# %%
import pandas as pd

# Load the CSV file into a DataFrame
flattenedYELPdata = pd.read_csv('..\\data\\flattenedYELPdata.csv')

# Get the shape of the DataFrame
num_rows, num_columns = flattenedYELPdata.shape
print("Total rows:", num_rows)
print("Total columns:", num_columns)
# Out:
# Total rows: 1080
# Total columns: 29

# %% [markdown]
# I would say that Yelp gave more complete data. Because the yelp API gives more detail and could see ratings of restaurants.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
import requests

# Function to get the top 10 restaurants in Hamilton using Yelp API
def get_top_restaurants_yelp(latitude, longitude, limit=10):
    API_KEY = 'hVV22ajvn0URrv13vqyEHqcvVNfUu7cNzfh2EVolQ55AKt2I7pI82ITKTHa2cvVqsFPPRlexP0TO29cn1GWZGhsu7_n5ZcnSUPaWV7hSPJz-vB8133SA5aatHNAgZnYx'  # Replace with your Yelp API key
    ENDPOINT = 'https://api.yelp.com/v3/businesses/search'

    headers = {
        'Authorization': f'Bearer {API_KEY}'
    }

    params = {
        'latitude': latitude,
        'longitude': longitude,
        'categories': 'restaurants',
        'limit': limit,
        'sort_by': 'rating'
    }

    response = requests.get(ENDPOINT, headers=headers, params=params)

    if response.status_code == 200:
        restaurants = response.json()['businesses']
        top_restaurants = []
        for restaurant in restaurants:
            restaurant_details = {
                "name": restaurant['name'],
                "rating": restaurant['rating']
            }
            top_restaurants.append(restaurant_details)
        return top_restaurants
    else:
        print("Failed to retrieve data from Yelp API.")
        return None

# Example usage:
latitude = 43.2563  # Example latitude (for a bike station in Hamilton, Ontario)
longitude = -79.8729  # Example longitude (for a bike station in Hamilton, Ontario)
top_restaurants_yelp = get_top_restaurants_yelp(latitude, longitude, limit=10)
if top_restaurants_yelp is not None:
    print("Top 10 Restaurants in Hamilton (Yelp):")
    for idx, restaurant in enumerate(top_restaurants_yelp, 1):
        print(f"{idx}. Name: {restaurant['name']}")
        print(f"   Rating: {restaurant['rating']}")
        print("----")
# Out:
# Top 10 Restaurants in Hamilton (Yelp):
# 1. Name: Tomah
#    Rating: 5.0
# ----
# 2. Name: Famous Recipe
#    Rating: 4.9
# ----
# 3. Name: Bon Temps
#    Rating: 4.9
# ----
# 4. Name: Mancala Monk Board Game Cafe
#    Rating: 4.9
# ----
# 5. Name: Rustic Reuben
#    Rating: 4.9
# ----
# 6. Name: Speedy Subs
#    Rating: 4.9
# ----
# 7. Name: 193 Bench Kitchen
#    Rating: 4.8
# ----
# 8. Name: Pita Pit
#    Rating: 4.8
# ----
# 9. Name: Cafe Baffico
#    Rating: 4.8
# ----
# 10. Name: Noodle and Dumpling
#    Rating: 4.8
# ----
